# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd

import os
os.chdir("D:\Git projects\CEPER\ceper_suc")

# %%
# %notebook "D:\Git projects\CEPER\ceper_suc\sucro.ipynb"

# %%
pd.read_excel('dados.xlsx')

# %%
pd.read_excel('dados.xlsx').plot()

# %%
pd.index
#pd.read_excel('dados.xlsx').plot()

# %%
df = pd.read_excel('dados.xlsx')

# %%
df

# %%
df.index

# %%
etan = pd.read_excel('dados.xlsx', sheet='etan')

# %%
etan = pd.read_excel('dados.xlsx', sheet_name='etan')

# %%
etan

# %%
etan = pd.read_excel('dados.xlsx', sheet_name='etan')

# %%
etan

# %%
etan.data

# %%
etan.data()

# %%
etan.iloc[:,['data']]

# %%
etan.loc[:,['data']]

# %%
etan.index = etan.loc[:,['data']]

# %%
etan

# %%
etan = pd.read_excel('dados.xlsx', sheet_name='etan')

# %%
etan.index = etan.data

# %%
etan

# %%
len(etan)

# %%
dim(etan)

# %%
shape(etan)

# %%
etan.shape

# %%
etan.shape[1]

# %%
etan[:,-etan.shape[1]:]

# %%
etan.iloc[:,-etan.shape[1]:]

# %%
etan.iloc[:,-(etan.shape[1]-1):]

# %%
etan = pd.read_excel('dados.xlsx', sheet_name='etan')
etan.index = etan.data
etan = etan.iloc[:,-(etan.shape[1]-1):]

# %%
etan

# %%
etan.plot()

# %%
etan.Brasil

# %%
etan

# %%
etan = pd.read_excel('dados.xlsx', sheet_name='etan')
#etan.index = etan.data
#etan = etan.iloc[:,-(etan.shape[1]-1):]

# %%
etan

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=10)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Indústria', color='crimson', marker='d', markersize=10)
ax.plot(etna.Anos, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=10)
ax.plot(etan.Anos, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=10)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
plt.legend(loc="center left", prop={'size': 16})
plt.xticks(np.arange(min(df2.Anos), max(df2.Anos)+1, 2.0), fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=10)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Indústria', color='crimson', marker='d', markersize=10)
ax.plot(etna.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=10)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=10)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
plt.legend(loc="center left", prop={'size': 16})
plt.xticks(np.arange(min(df2.Anos), max(df2.Anos)+1, 2.0), fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=10)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Indústria', color='crimson', marker='d', markersize=10)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=10)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=10)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
plt.legend(loc="center left", prop={'size': 16})
plt.xticks(np.arange(min(df2.Anos), max(df2.Anos)+1, 2.0), fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=10)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Indústria', color='crimson', marker='d', markersize=10)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=10)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=10)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
plt.legend(loc="center left", prop={'size': 16})
#plt.xticks(np.arange(min(df2.Anos), max(df2.Anos)+1, 2.0), fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=10)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Indústria', color='crimson', marker='d', markersize=10)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=10)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=10)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
plt.legend(loc="center left", prop={'size': 16})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Indústria', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
plt.legend(loc="center left", prop={'size': 16})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Indústria', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          ncol=3, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Indústria', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.5),
          ncol=3, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Indústria', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=3, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=3, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='bottom center', bbox_to_anchor=(0.5, 1.05), ncol=3, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='lower center', bbox_to_anchor=(0.5, 1.05), ncol=3, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=3, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(1.5, 1.05), ncol=3, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=3, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', ncol=3, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), ncol=3, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), ncol=4, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05), ncol=4, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.05), ncol=4, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.5), ncol=4, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=4, fancybox=True, shadow=True)
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=4, fancybox=True, shadow=True, prop={'size': 16})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#plt.legend(loc="center left", prop={'size': 16})
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=4, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='gold', marker='X', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=4, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='gold', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=4, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='gold', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='chartreuse', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms, type='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms, type='-')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms, line='-')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms,  linestyle='-')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', marker='o', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray',', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=20, rotation=45)
plt.yticks(fontsize=20)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.3), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd
import matplotlib.ticker as mtick
import locale
locale.setlocale(locale.LC_NUMERIC, "de_DE")


plt.rcParams['axes.formatter.use_locale'] = True



import os
os.chdir("D:\Git projects\CEPER\ceper_suc")

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.YearLocator(step, month = 1, day = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd
import matplotlib.ticker as mtick
import locale
locale.setlocale(locale.LC_NUMERIC, "de_DE")


plt.rcParams['axes.formatter.use_locale'] = True


import matplotlib.dates as md

import os
os.chdir("D:\Git projects\CEPER\ceper_suc")

# %%
ms =5

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.YearLocator(step, month = 1, day = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.YearLocator(step, month = 1, day = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.YearLocator(step, month = 1, day = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.YearLocator(step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.YearLocator(step, month = 10, day = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
#ax.xaxis.set_major_locator(md.YearLocator(step, month = 10, day = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=10

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.YearLocator(step, month = 10, day = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.YearLocator(step, month = 10, day = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.YearLocator(step, month = 1, day = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.YearLocator(step, month = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.YearLocator(step, interval = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.MonthLocator(step, month = 1, day = 1))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y')
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=1

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y')
ax.xaxis.set_major_locator(md.MonthLocator(interval=2))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y')
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='red', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='*', markersize=ms)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='*', markersize=ms+1)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='1', markersize=ms+1)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='h', markersize=ms+1)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms+1)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms+1)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lwd=1)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms+1)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=1)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--')
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms+1)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=0.5)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3
lw=0.5

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =5
step=3
lw=2

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(10,8))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.eps", format='eps', dpi=2000)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
plt.savefig("C:/Users/user/Downloads/Thesis_paper_1/paper_tex/fig1.png", format='png', dpi=2000)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png", format='png')

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")
plt.savefig('fig1.png')

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")
plt.savefig('fig1.png', dpi=100)

# %%
fig

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")
plt.show()
plt.savefig('fig1.png', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig1.png', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig1.jpg', dpi=100)

# %%
plt.savefig('fig1.eps', format='eps', dpi=1000)

# %%
gasol = pd.read_excel('dados.xlsx', sheet_name='gasol')

# %%
gasol = pd.read_excel('dados.xlsx', sheet_name='gasol')

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(gasol.data, gasol.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(gasol.data, gasol[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(gasol.data, gasol['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do gasolol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(gasol.data, gasol.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(gasol.data, gasol[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(gasol.data, gasol['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real da gasolina comum", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
diesel = pd.read_excel('dados.xlsx', sheet_name='diesel')

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(diesel.data, diesel.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(diesel.data, diesel[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(diesel.data, diesel['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do óleo diesel", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
diesel = pd.read_excel('dados.xlsx', sheet_name='diesel')

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(diesel.data, diesel.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(diesel.data, diesel[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(diesel.data, diesel['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do óleo diesel", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(diesel.data, diesel.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(diesel.data, diesel[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(diesel.data, diesel['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do óleo diesel", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig3.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(gasol.data, gasol.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(gasol.data, gasol[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(gasol.data, gasol['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real da gasolina comum", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
petr = pd.read_excel('dados.xlsx', sheet_name='petr')

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+2)

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1)

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%Y/%m'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1)

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
petr

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1)

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1)

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper left', fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1, marker='o')

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper left', fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1, marker='o')

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper left', fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig4.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(diesel.data, diesel.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(diesel.data, diesel[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(diesel.data, diesel['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do óleo diesel", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig3.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(diesel.data, diesel.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(diesel.data, diesel[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(diesel.data, diesel['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(diesel.data, diesel['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do óleo diesel", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4), ncol=3, fancybox=False, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig3.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1, marker='o')

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
#ax.legend(loc='upper left', fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig4.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(gasol.data, gasol.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(gasol.data, gasol[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(gasol.data, gasol['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real da gasolina comum", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(gasol.data, gasol.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(gasol.data, gasol[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(gasol.data, gasol['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(gasol.data, gasol['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real da gasolina \n comum", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig2.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(etan.data, etan.Brasil, label ='Brasil', color='gray', markersize=ms,  linestyle='--', lw=lw)
ax.plot(etan.data, etan[['Ribeirão Preto']], label='Ribeirão Preto', color='crimson', marker='d', markersize=ms, lw=lw)
ax.plot(etan.data, etan[['Araraquara']], label='Araraquara', color='orange', marker='s', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São José do Rio Preto'],  label='São José do Rio Preto', color='blue', marker='v', markersize=ms, lw=lw)
ax.plot(etan.data, etan['São Paulo (capital)'],  label='São Paulo (capital)', color='maroon', marker='+', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Estado de SP'],  label='Estado de SP', color='green', marker='X', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Sertãozinho'],  label='Sertãozinho', color='cyan', marker='p', markersize=ms, lw=lw)
ax.plot(etan.data, etan['Franca'],  label='Franca', color='indigo', marker='o', markersize=ms,  lw=lw)
ax.plot(etan.data, etan['Campinas'],  label='Campinas', color='yellow', marker='x', markersize=ms, lw=lw)


ax.set_ylabel("Preço real do Etanol", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.4), ncol=3, fancybox=True, shadow=True, prop={'size': 12})
plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig1.jpg', dpi=100)

# %%
petr

# %%
petr

# %%
petr.data=='2021-01-01'

# %%
petr[petr.data=='2021-01-01']

# %%
petr[petr.data=='2021-01-01'][0]

# %%
petr[petr.data=='2021-01-01']

# %%
petr[petr.data=='2021-01-01', 'petr']

# %%
petr.iloc[petr.data=='2021-01-01', 'petr']

# %%
petr.loc[petr.data=='2021-01-01', 'petr']

# %%
petr[48]

# %%
petr[48,]

# %%
petr[48,:]

# %%
petr.iloc[48,:]

# %%
petr.loc[petr.data=='2021-01-01', 'petr'][0]

# %%
petr.loc[petr.data=='2021-01-01', 'petr']

# %%
petr.loc[[petr.data=='2021-01-01', 'petr']]

# %%
petr[[petr.data=='2021-01-01', 'petr']]

# %%
petr[[petr.data=='2021-01-01']]

# %%
petr.loc[petr.data=='2021-01-01', 'petr']]

# %%
petr.loc[petr.data=='2021-01-01', 'petr']

# %%
petr.iloc[petr.data=='2021-01-01', 'petr']

# %%
petr.iloc[[petr.data=='2021-01-01'], ['petr']]

# %%
petr.loc[[petr.data=='2021-01-01'], ['petr']]

# %%
petr.loc[petr.data=='2021-01-01', ['petr']]

# %%
petr.iloc[48]

# %%
dim(petr)

# %%
petr.dim

# %%
petr.dim()

# %%
petr.shape()

# %%
petr.shape

# %%
petr.shape[0]

# %%
petr.shape[0]-1

# %%
petr.iloc[48, 1]

# %%
petr.iloc[petr.shape[0]-1, 1]

# %%
petr.loc[petr.data=='2021-01-01', ['petr']]

# %%
petr.loc[petr.data=='2021-01-01', :]

# %%
petr.loc[petr.data=='2021-01-01', :][0]

# %%
petr.loc[petr.data=='2021-01-01', 'data']

# %%
petr.loc[petr.data=='2021-01-01', ['data']]

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1, marker='o')

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.text(petr.loc[petr.data=='2021-01-01', ['data']], petr.loc[petr.data=='2021-01-01', ['petr']], '53,60')

plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig4.jpg', dpi=100)

# %%
petr.loc[petr.data=='2021-01-01', 'data']

# %%
np.array(petr.loc[petr.data=='2021-01-01', 'data'] )

# %%
petr.loc[petr.data=='2021-01-01', 'data']

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1, marker='o')

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.text(petr.loc[petr.data=='2021-01-01', 'data'], petr.loc[petr.data=='2021-01-01', 'petr'], '53,60')

plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig4.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1, marker='o')

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.text(petr.loc[petr.data=='2021-01-01', 'data'], petr.loc[petr.data=='2021-01-01', 'petr']+0.4, '53,60', fontsize=12)

plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig4.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1, marker='o')

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.text(petr.loc[petr.data=='2021-01-01', 'data'], petr.loc[petr.data=='2021-01-01', 'petr']+0.8, '53,60', fontsize=12)

plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig4.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1, marker='o')

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.text(petr.loc[petr.data=='2021-01-01', 'data'], petr.loc[petr.data=='2021-01-01', 'petr']+1.2, '53,60', fontsize=12)

plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig4.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1, marker='o')

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.text(petr.loc[petr.data=='2021-01-01', 'data'], petr.loc[petr.data=='2021-01-01', 'petr']+1.3, '53,60', fontsize=12)

plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig4.jpg', dpi=100)

# %%
ms =7
step=3
lw=0.8

fig,ax = plt.subplots(figsize=(12,6))
ax.plot(petr.data, petr.petr, label ='Petróleo', color='blue', markersize=ms,  linestyle='-', lw=lw+1, marker='o')

ax.set_ylabel("Preço real do barril de pétróleo", fontsize=18)
ax.set_xlabel("Período", fontsize=18)
ax.text(petr.loc[petr.data=='2021-01-01', 'data'], petr.loc[petr.data=='2021-01-01', 'petr']+1.5, '53,60', fontsize=12)

plt.xticks(fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.grid(True, axis='y', color='k', linestyle=':', lw=.5)
ax.xaxis.set_major_locator(md.MonthLocator(interval=step))
ax.xaxis.set_major_formatter(md.DateFormatter('%m/%Y'))
plt.tight_layout()    
#plt.savefig("D:/Git projects/CEPER/ceper_suc/fig1.png")

plt.savefig('fig4.jpg', dpi=100)
